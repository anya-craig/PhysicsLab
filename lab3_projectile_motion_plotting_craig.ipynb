# %% [markdown]
# <a href="https://colab.research.google.com/github/anya-craig/PhysicsLab/blob/main/lab3_projectile_motion_plotting_craig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PHSX 216 & 218 plotting code
#Brianna Beller
#Updated September 2023

import numpy as np
import matplotlib.pyplot as plt


# %matplotlib inline

#-----------------------------------------------------------------------#
#Data Section - Create Arrays for data. Perform necessary calculations.
#CHANGE THE VARIABLE NAMES and numbers to match your data

xvariable_theta= np.array([35.63, 38.63, 41.63, 44.63, 47.63]) #what are units? degrees
yvariable_averageheightofimpact= np.array([0.6436, 0.7322, 0.762, 0.7394, 0.7116]) #what are units? meters

#-----------------------------------------------------------------------#
#Create array for uncertainties in y variable
#CHANGE THE VARIABLE NAME and numbers to match your data

err_yvariable_averageheightofimpact= np.array([0.0309,0.0315,0.0236,0.0236,0.0186])

#-----------------------------------------------------------------------#
#--------------------------Plotting Code Below--------------------------#
#-----------------------------------------------------------------------#

#UPDATE THIS SECTION!!!

#Re-assign variables as x, y, dy so that the remaining plotting code may remain generic
x = xvariable_theta             #this should be the array you want to plot on the x axis
y = yvariable_averageheightofimpact           #this should be the array you want to plot on the y axis
dy = err_yvariable_averageheightofimpact      #this should be your error in y array


#update each of these 4 strings
plot_title= 'average height of impact vs. angle of projection'
x_label= 'theta (degrees)'
y_label= 'average height of impact (m)'


#-----------------------------------------------------------------------#
#Don't need to change anything in this section!


#size the plot
plt.figure(figsize=(15,10))

#create scatter plot
plt.scatter(x, y, color='blue', marker='o')

#create labels
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)

#fitting to a 2nd degree polynomial
c,b,a=np.polynomial.polynomial.polyfit(x,y,2,w=dy)

#Annotate with values of A, B, C from best fit polynomial
plt.annotate('A = {value:.{digits}E}'.format(value=a, digits=3),
             (0.05, 0.9), xycoords='axes fraction')

plt.annotate('B = {value:.{digits}E}'.format(value=b, digits=3),
             (0.05, 0.85), xycoords='axes fraction')

plt.annotate('C = {value:.{digits}E}'.format(value=c, digits=3),
             (0.05, 0.8), xycoords='axes fraction')
#Create fit line
xnew = np.linspace(x.min(), x.max(), 300)
fit = a*xnew**2 + b*xnew +c

plt.plot(xnew, fit, color='green')
plt.show()
